# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("unemployment_benefits_data - unemployment_rates.csv")

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df, x='period', y='unemployment rate', hue='state')
# Out:
# <AxesSubplot:xlabel='period', ylabel='unemployment rate'>

# %%
filtered_df=df[df['period'] > '2019-12']

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=filtered_df, x='period', y='unemployment rate', hue='state')
# Out:
# <AxesSubplot:xlabel='period', ylabel='unemployment rate'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              500 non-null    object
#  1   period             500 non-null    object
#  2   unemployment rate  500 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 11.8+ KB
